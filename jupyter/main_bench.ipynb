# %%
# %autoreload 2

# %run ../src/qp_transform/main.py
# Out:
# alpha is currently set to: 1.00e-03
# sampling rate is currently set to: 4096
# Running a benchmark for the event GW150914-v3 at LIGO Livingston:
# get_tau_phi_plane   :    CPU:  1191.207 us   +/- 200.880 (min:   984.800 / max:  2663.700) us     GPU-0:  7843.935 us   +/- 7135.160 (min:  6160.384 / max: 59036.671) us
# Running a benchmark for the event GW150914-v3 at LIGO Hanford:
# get_tau_phi_plane   :    CPU:  1278.671 us   +/- 221.598 (min:   984.100 / max:  2104.600) us     GPU-0:  8345.567 us   +/- 3722.959 (min:  6153.216 / max: 24743.937) us
# Running a benchmark for the event GW190521-v2 at LIGO Livingston:
# get_tau_phi_plane   :    CPU:  1215.940 us   +/- 142.748 (min:  1006.900 / max:  1653.000) us     GPU-0:  8021.797 us   +/- 4168.995 (min:  6225.920 / max: 23536.640) us
# Running a benchmark for the event GW190521-v2 at LIGO Hanford:
# ...
