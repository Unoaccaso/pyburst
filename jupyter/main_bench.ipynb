# %%
# %autoreload 2

# %run ../src/qp-transform/main.py
# Out:
# Downloaing 'GW150914-v3' data from 'L1'.
# Fetched 1 URLs from gwosc.org for [1126259452 .. 1126259473))
# Reading data... [Done]
# Downloaing 'GW150914-v3' data from 'H1'.
# Fetched 1 URLs from gwosc.org for [1126259452 .. 1126259473))
# Reading data... [Done]
# alpha is currently set to: 1.00e-03
# sampling rate is currently set to: 4096
# Running a benchmark for the event GW150914-v3 at LIGO Livingston:
# qp_transform        :    CPU:  1513.826 us   +/- 713.412 (min:  1142.400 / max:  7593.000) us     GPU-0:  7874.454 us   +/- 8540.884 (min:  5793.568 / max: 59870.209) us
# Running a benchmark for the event GW150914-v3 at LIGO Hanford:
# qp_transform        :    CPU:  1423.908 us   +/- 344.179 (min:  1149.500 / max:  3944.200) us     GPU-0:  7314.911 us   +/- 2543.529 (min:  5818.368 / max: 16386.047) us
# Plotting...
