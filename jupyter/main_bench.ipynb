# %%
# %autoreload 2

# %run ../src/qp-transform/main.py
# Out:
# c:\Users\felic\miniconda3\envs\qp-transform\Lib\site-packages\cupyx\jit\_interface.py:173: FutureWarning: cupyx.jit.rawkernel is experimental. The interface can change in the future.
#   cupy._util.experimental('cupyx.jit.rawkernel')
# Downloaing 'GW150914-v3' data from 'L1'.
# Fetched 1 URLs from gwosc.org for [1126259452 .. 1126259473))
# Reading data... [Done]
# Downloaing 'GW150914-v3' data from 'H1'.
# Fetched 1 URLs from gwosc.org for [1126259452 .. 1126259473))
# Reading data... [Done]
# Downloaing 'GW190521-v2' data from 'L1'.
# Fetched 1 URLs from gwosc.org for [1242442957 .. 1242442978))
# Reading data... [Done]
# Downloaing 'GW190521-v2' data from 'H1'.
# Fetched 1 URLs from gwosc.org for [1242442957 .. 1242442978))
# Reading data... [Done]
# alpha is currently set to: 1.00e-01
# sampling rate is currently set to: 2048
# 100%|██████████| 50/50 [00:08<00:00,  6.04it/s]
# Best fit for Q and p: (9.361, 0.122)
# 100%|██████████| 50/50 [00:09<00:00,  5.36it/s]
# ...
