# %%
import gwpy.timeseries

# %%
arr = gwpy.timeseries.TimeSeries([1, 2, 3])
arr.whiten()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/timeseries/ts-vnv/lib/python3.11/site-packages/gwpy/signal/spectral/_ui.py:283, in _psdn(timeseries, method_func, *args, **kwargs)
#     282 try:
# --> 283     timeseries, other = timeseries
#     284 # or just calculate PSD
#
# ValueError: too many values to unpack (expected 2)
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 arr = gwpy.timeseries.TimeSeries([1, 2, 3])
# ----> 2 arr.whiten()
#
# File ~/timeseries/ts-vnv/lib/python3.11/site-packages/gwpy/timeseries/timeseries.py:1791, in TimeSeries.whiten(self, fftlength, overlap, method, window, detrend, asd, fduration, highpass, **kwargs)
#    1789 fftlength = fftlength if fftlength else _fft_length_default(self.dt)
# ...

# %%
import scipy.signal

scipy.signal.welch
