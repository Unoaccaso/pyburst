# %%
# %autoreload 2
# %run ../src/qp_transform/main.py
# Out:
# Fetched 1 URLs from gwosc.org for [1126259452 .. 1126259473))
# Reading data... [Done]
# Running a benchmark on custom kernel:
# get_tau_phi_plane_cuda:    CPU:  1281.929 us   +/- 156.276 (min:  1065.800 / max:  1941.900) us     GPU-0: 24831.625 us   +/- 2409.356 (min: 24097.792 / max: 38692.863) us
# Running a benchmark on cupy version:
# get_tau_phi_plane_cp:    CPU:  1164.728 us   +/- 192.497 (min:   974.300 / max:  2058.600) us     GPU-0:  5282.401 us   +/- 161.374 (min:  4854.464 / max:  6003.712) us
