# %% [markdown]
# <pre>
# timeserie
# ├── __init__.py
# │   ├── from timeserie.core.timeserie import TimeSerie
# │   ├── from timeserie.core.signal import (fft, ifft, fftfreq, whiten, resample)
# │   ├── from timeserie.convert import (from_numpy, from_cupy, from_dask, from_gwpy)
# │   ├── from timeserie.download import fetch_name, fetch_gps
# │   ├── from timeserie.backends.api import from_file
# │   ├── from timeserir.caching import TimeSeriesCache
# │   └── cache = TimeSeriesCache()
# ├── core
# │   ├── __init__.py
# │   ├── __init__.pyi
# │   ├── timeserie.py
# │   ├── timeserie.pyi
# │   │   ├── _BaseTimeSerie
# │   │   │   └── save()
# │   │   ├── CPUTimeSerie
# │   │   ├── GPUTimeSerie
# │   │   └── LazyTimeSerie
# │   ├── signal.py
# │   └── signal.pyi
# │       ├── fft()
# │       ├── ifft()
# │       ├── fftfreq()
# │       ├── whiten()
# │       └── resample()
# ├── backends
# │   ├── __init__.py
# │   ├── __init__.pyi
# │   ├── api.py
# │   ├── api.pyi
# │   │   └── from_file()
# │   ├── zarr.py
# │   └── zarr.pyi
# ├── common
# │   └── _typing.py
# │       └── type_check()
# ├── convert.py
# ├── convert.pyi
# │   ├── from_numpy()
# │   ├── from_cupy()
# │   ├── from_dask()
# │   └── from_gwpy()
# ├── download.py
# ├── download.pyi
# │   ├── fetch_name()
# │   └── fethc_gps()
# ├── caching.py
# └── caching.pyi
#     └── LRUCache
#         └── append()
# </pre>
