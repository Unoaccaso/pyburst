# %% [markdown]
# Signal module revision
# ======================

# %%
from gwpy.timeseries import TimeSeries
import gwosc.datasets

def fetch_open_data(*args, duration: int = 100, **kwargs):
    gps_time = gwosc.datasets.event_gps(args[0])
    start = gps_time - duration / 2
    stop = gps_time + duration /2
    return TimeSeries.fetch_open_data(*args, start=start, stop=stop, **kwargs)

# %%
fetch_open_data('GW150914-v3')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/qp-transform/lib/python3.11/site-packages/gwosc/api.py:62, in fetch_json(url, **kwargs)
#      61 try:
# ---> 62     return JSON_CACHE[url]
#      63 except KeyError:
#
# KeyError: 'https://gwosc.org/eventapi/json/allevents/'
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# File ~/.conda/envs/qp-transform/lib/python3.11/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# ...
